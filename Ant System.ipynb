# %%
import ACOAs
import RTSP
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # 1. Random Graph generator default parameters:
# RandGraph(dim = 10, domain = (2,4))

# %%
GRAPH = RTSP.RandGraph(20, (10,20))

# np.array(GRAPH)
g = nx.Graph() 

for i in range(len(GRAPH)):
    edges = [(i, k) for k,j in enumerate(GRAPH[i]) if j>0]
    for edge in edges:
        g.add_edge(edge[0], edge[1])

nx.draw(g, with_labels = True)

# %%
hm = plt.imshow(GRAPH, 'gray', origin='lower')

plt.colorbar(hm)

# %% [markdown]
# # 2. Ant Sytem default parameters:
#
# AS(costGraph, Population = 8, alpha = 1, beta = 3, rho = 0.5, iterations = 100, dropout = False, show = False)

# %%
Population = 10
alpha = 1
beta = 3
rho = 0.5
generations = 500
dropout = False
show = False

for i in range(10):
    SOLUTION = ACOAs.AS(GRAPH, Population = 10, alpha = 1, beta = 3, rho = 0.5, iterations = generations,
                    dropout = False, show = False)
    print(SOLUTION["BSF"])
# Out:
# 240.6382065688576
# 241.65758418256038
# 239.7272765899718
# 238.4252227717318
# 243.86995927627856
# 243.2071462822728
# 231.31645675349537
# 241.45859619436612
# 244.16452661197405
# 243.94102769550594

# %%
hm = plt.imshow(SOLUTION["PRM"], 'gray', origin='lower')
plt.colorbar(hm)

# %%
for i in range(10):
    SOLUTION = ACOAs.AS(GRAPH, Population = 10, alpha = 1, beta = 3, rho = 0.5, iterations = generations,
                    dropout = True, show = False)
    print(SOLUTION["BSF"])
# Out:
# 239.72293408401876
# 240.53690680803697
# 245.3693298180748
# 241.25814928811764
# 242.0227833872951
# 243.62955785610637
# 244.41585349813238
# 240.67324519243283
# 241.57220749380255
# 240.51306876519283

# %%
hm = plt.imshow(SOLUTION["PRM"], 'gray', origin='lower')
plt.colorbar(hm)
