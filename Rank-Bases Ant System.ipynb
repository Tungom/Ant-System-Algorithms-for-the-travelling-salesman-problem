# %%
import ACOAs
import RTSP
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # 1. Random Graph generator default parameters:
# RandGraph(dim = 10, domain = (2,4))

# %%
GRAPH = RTSP.RandGraph(20, (10,20))

# np.array(GRAPH)
g = nx.Graph() 

for i in range(len(GRAPH)):
    edges = [(i, k) for k,j in enumerate(GRAPH[i]) if j>0]
    for edge in edges:
        g.add_edge(edge[0], edge[1])

nx.draw(g, with_labels = True)

# %%
hm = plt.imshow(GRAPH, 'gray', origin='lower')

plt.colorbar(hm)

# %% [markdown]
# # 2. Rank Based Ant Sytem default parameters:
#
# Population = 8, alpha = 1, beta = 3, rho = 0.1, iterations = 100, dropout = False, show = False):

# %%
Population = 10
alpha = 1
beta = 3
rho = 0.1
generations = 500
dropout = False
show = False

for i in range(10):
    SOLUTION = ACOAs.RBAS(GRAPH, Population = 10, alpha = 1, beta = 3, rho = 0.5, iterations = generations,
                    dropout = False, show = False)
    print(SOLUTION["BSF"])
# Out:
# 240.13003684543287
# 237.26661812986168
# 235.488262767062
# 238.90886445399403
# 237.76887325496904
# 241.05378712125665
# 234.1572836424458
# 238.31511530949905
# 236.71751108037657
# 236.61053134442474

# %%
hm = plt.imshow(SOLUTION["PRM"], 'gray', origin='lower')
plt.colorbar(hm)

# %%
for i in range(10):
    SOLUTION = ACOAs.RBAS(GRAPH, Population = 10, alpha = 1, beta = 3, rho = 0.5, iterations = generations,
                    dropout = True, show = False)
    print(SOLUTION["BSF"])
# Out:
# 236.54413884511695
# 237.29544424817192
# 236.1728233601379
# 238.34294228140323
# 233.30418615721695
# 236.65866241922285
# 239.96065249604695
# 240.18074613514145
# 238.247601205969
# 238.58360473645286

# %%
hm = plt.imshow(SOLUTION["PRM"], 'gray', origin='lower')
plt.colorbar(hm)
