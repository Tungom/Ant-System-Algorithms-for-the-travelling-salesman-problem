# %%
import ACOAs
import RTSP
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # 1. Random Graph generator default parameters:
# RandGraph(dim = 10, domain = (2,4))

# %%
GRAPH = RTSP.RandGraph(20, (10,20))

# np.array(GRAPH)
g = nx.Graph() 

for i in range(len(GRAPH)):
    edges = [(i, k) for k,j in enumerate(GRAPH[i]) if j>0]
    for edge in edges:
        g.add_edge(edge[0], edge[1])

nx.draw(g, with_labels = True)

# %%
hm = plt.imshow(GRAPH, 'gray', origin='lower')

plt.colorbar(hm)

# %% [markdown]
# # 2. Max-Min Ant Sytem default parameters:
#
# MMAS(costGraph, Population = 8, alpha = 1, beta = 3, rho = 0.02, iterations = 100, dropout = False, show = False):

# %%
Population = 10
alpha = 1
beta = 3
rho = 0.1
generations = 500
dropout = False
show = False

for i in range(10):
    SOLUTION = ACOAs.MMAS(GRAPH, Population = 10, alpha = 1, beta = 3, rho = 0.5, iterations = generations,
                    dropout = False, show = False)
    print(SOLUTION["BSF"])
# Out:
# 222.71876627296314
# 228.4068887027982
# 224.51227951277036
# 230.3904740862782
# 228.1441859645747
# 230.5907530001205
# 231.36710480805976
# 230.23489373465466
# 225.98787412574683
# 227.36945709558339

# %%
hm = plt.imshow(SOLUTION["PRM"], 'gray', origin='lower')
plt.colorbar(hm)

# %%
for i in range(10):
    SOLUTION = ACOAs.MMAS(GRAPH, Population = 10, alpha = 1, beta = 3, rho = 0.5, iterations = generations,
                    dropout = True, show = False)
    print(SOLUTION["BSF"])
# Out:
# 231.76490525623606
# 228.775103799669
# 226.66887537114258
# 225.39768126143483
# 230.5967244205936
# 226.19905589634521
# 231.89309796890095
# 227.22657506924398
# 228.9443036862898
# 228.57210725956043

# %%
hm = plt.imshow(SOLUTION["PRM"], 'gray', origin='lower')
plt.colorbar(hm)
